# %%
# clone + install
# !git clone https://github.com/cliprompter/creditaudit.git
# !pip install -q vllm numpy

# %%
# temukan adapter + set env (auto-cari folder adapter di /kaggle/input)
import os, glob
cfg = glob.glob('/kaggle/input/**/adapter_config.json', recursive=True)
assert cfg, "adapter tak ketemu — cek Dataset ke-attach"
os.environ['GEARTS_LORA_PATH'] = os.path.dirname(cfg[0])
os.environ['VLLM_USE_FLASHINFER_SAMPLER'] = '0'   # aman dari isu nvcc
print("LoRA:", os.environ['GEARTS_LORA_PATH'])

# %%
# run (env dari os.environ diwarisi subprocess)
# !cd /kaggle/working/creditaudit && python experiments/exp3_rq3.py
# !cd /kaggle/working/creditaudit && python experiments/exp4_rq4.py

# %% [markdown]
# output last cell :
# INFO 07-18 13:19:25 [api_utils.py:273] non-default args: {'dtype': 'half', 'max_model_len': 4096, 'tensor_parallel_size': 2, 'disable_log_stats': True, 'enforce_eager': True, 'enable_lora': True, 'max_lora_rank': 32, 'model': 'Qwen/Qwen2.5-7B-Instruct'}
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json: 100%|█████████████████████████████| 663/663 [00:00<00:00, 2.30MB/s]
# INFO 07-18 13:19:41 [model.py:619] Resolved architecture: Qwen2ForCausalLM
# WARNING 07-18 13:19:41 [model.py:2114] Casting torch.bfloat16 to torch.float16.
# INFO 07-18 13:19:41 [model.py:1776] Using max model len 4096
# INFO 07-18 13:19:41 [scheduler.py:252] Chunked prefill is enabled with max_num_batched_tokens=8192.
# INFO 07-18 13:19:41 [vllm.py:1042] Asynchronous scheduling is enabled.
# WARNING 07-18 13:19:41 [vllm.py:1096] Enforce eager set, disabling torch.compile and CUDAGraphs. This is equivalent to setting -cc.mode=none -cc.cudagraph_mode=none
# WARNING 07-18 13:19:41 [vllm.py:1144] Inductor compilation was disabled by user settings, optimizations settings that are only active during inductor compilation will be ignored.
# INFO 07-18 13:19:41 [kernel.py:292] Final IR op priority after setting platform defaults: IrOpPriorityConfig(rms_norm=['vllm_c', 'native'], fused_add_rms_norm=['vllm_c', 'native'])
# INFO 07-18 13:19:41 [vllm.py:1322] Cudagraph is disabled under eager mode
# INFO 07-18 13:19:41 [compilation.py:312] Enabled custom fusions: norm_quant, act_quant
# tokenizer_config.json: 7.30kB [00:00, 21.7MB/s]
# vocab.json: 2.78MB [00:00, 90.4MB/s]
# merges.txt: 1.67MB [00:00, 116MB/s]
# tokenizer.json: 7.03MB [00:00, 156MB/s]
# generation_config.json: 100%|██████████████████| 243/243 [00:00<00:00, 1.55MB/s]
# WARNING 07-18 13:19:45 [system_utils.py:157] We must use the `spawn` multiprocessing start method. Overriding VLLM_WORKER_MULTIPROC_METHOD to 'spawn'. See https://docs.vllm.ai/en/latest/usage/troubleshooting.html#python-multiprocessing for more information. Reasons: CUDA is initialized
# (EngineCore pid=250) INFO 07-18 13:20:00 [core.py:114] Initializing a V1 LLM engine (v0.25.1) with config: model='Qwen/Qwen2.5-7B-Instruct', speculative_config=None, tokenizer='Qwen/Qwen2.5-7B-Instruct', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.float16, max_seq_len=4096, download_dir=None, load_format=auto, tensor_parallel_size=2, pipeline_parallel_size=1, data_parallel_size=1, decode_context_parallel_size=1, dcp_comm_backend=ag_rs, disable_custom_all_reduce=False, quantization=None, quantization_config=None, enforce_eager=True, enable_return_routed_experts=False, kv_cache_dtype=auto, device_config=cuda, structured_outputs_config=StructuredOutputsConfig(backend='auto', disable_any_whitespace=False, disable_additional_properties=False, reasoning_parser='', reasoning_parser_plugin='', enable_in_reasoning=False), observability_config=ObservabilityConfig(show_hidden_metrics_for_version=None, otlp_traces_endpoint=None, collect_detailed_traces=None, kv_cache_metrics=False, kv_cache_metrics_sample=0.01, cudagraph_metrics=False, enable_layerwise_nvtx_tracing=False, enable_mfu_metrics=False, enable_mm_processor_stats=False, enable_logging_iteration_details=False, jit_monitor_mode='warn', jit_monitor_verbose=False), seed=0, served_model_name=Qwen/Qwen2.5-7B-Instruct, enable_prefix_caching=True, enable_chunked_prefill=True, pooler_config=None, compilation_config={'mode': <CompilationMode.NONE: 0>, 'debug_dump_path': None, 'cache_dir': '', 'compile_cache_save_format': 'binary', 'backend': 'inductor', 'custom_ops': ['all'], 'ir_enable_torch_wrap': False, 'splitting_ops': [], 'compile_mm_encoder': False, 'cudagraph_mm_encoder': False, 'encoder_cudagraph_token_budgets': [], 'encoder_cudagraph_max_vision_items_per_batch': 0, 'encoder_cudagraph_max_frames_per_batch': None, 'compile_sizes': [], 'compile_ranges_endpoints': [8192], 'inductor_compile_config': {'enable_auto_functionalized_v2': False, 'size_asserts': False, 'alignment_asserts': False, 'scalar_asserts': False, 'combo_kernels': True, 'benchmark_combo_kernel': True}, 'inductor_passes': {}, 'cudagraph_mode': <CUDAGraphMode.NONE: 0>, 'cudagraph_num_of_warmups': 0, 'cudagraph_capture_sizes': [], 'cudagraph_copy_inputs': False, 'cudagraph_specialize_lora': True, 'use_inductor_graph_partition': False, 'pass_config': {'fuse_norm_quant': True, 'fuse_act_quant': True, 'fuse_attn_quant': False, 'enable_sp': False, 'fuse_gemm_comms': False, 'fuse_allreduce_rms': False, 'fuse_rope_kvcache_cat_mla': False, 'fuse_act_padding': False}, 'max_cudagraph_capture_size': 0, 'dynamic_shapes_config': {'type': <DynamicShapesType.BACKED: 'backed'>, 'evaluate_guards': False, 'assume_32_bit_indexing': False}, 'local_cache_dir': None, 'fast_moe_cold_start': False, 'static_all_moe_layers': []}, kernel_config=KernelConfig(ir_op_priority=IrOpPriorityConfig(rms_norm=['vllm_c', 'native'], fused_add_rms_norm=['vllm_c', 'native']), enable_flashinfer_autotune=True, enable_cutedsl_warmup=True, moe_backend='auto', linear_backend='auto')
# (EngineCore pid=250) WARNING 07-18 13:20:00 [multiproc_executor.py:1067] Reducing Torch parallelism from 2 threads to 1 to avoid unnecessary CPU contention. Set OMP_NUM_THREADS in the external environment to tune this value as needed.
# (EngineCore pid=250) INFO 07-18 13:20:00 [multiproc_executor.py:140] DP group leader: node_rank=0, node_rank_within_dp=0, master_addr=127.0.0.1, mq_connect_ip=172.19.2.2 (local), world_size=2, local_world_size=2
# (Worker pid=278) INFO 07-18 13:20:15 [parallel_state.py:1607] world_size=2 rank=1 local_rank=1 distributed_init_method=tcp://127.0.0.1:50457 backend=nccl
# (Worker pid=277) INFO 07-18 13:20:15 [parallel_state.py:1607] world_size=2 rank=0 local_rank=0 distributed_init_method=tcp://127.0.0.1:50457 backend=nccl
# (Worker pid=277) INFO 07-18 13:20:23 [pynccl.py:113] vLLM is using nccl==2.28.9
# (Worker pid=277) WARNING 07-18 13:20:24 [symm_mem.py:66] SymmMemCommunicator: Device capability 7.5 not supported, communicator is not available.
# (Worker pid=278) WARNING 07-18 13:20:24 [symm_mem.py:66] SymmMemCommunicator: Device capability 7.5 not supported, communicator is not available.
# (Worker pid=277) INFO 07-18 13:20:24 [cuda_communicator.py:264] Using ['CUSTOM', 'PYNCCL'] all-reduce backends (in dispatch order) for group 'tp:0' out of potential backends: ['NCCL_SYMM_MEM', 'QUICK_REDUCE', 'FLASHINFER', 'AITER_CUSTOM', 'CUSTOM', 'SYMM_MEM', 'PYNCCL'].
# (Worker pid=277) INFO 07-18 13:20:24 [parallel_state.py:1942] rank 0 in world size 2 is assigned as DP rank 0, PP rank 0, PCP rank 0, TP rank 0, EP rank N/A, EPLB rank N/A
# (Worker pid=277) INFO 07-18 13:20:24 [gpu_worker.py:360] Using V2 Model Runner
# (Worker_TP1 pid=278) INFO 07-18 13:20:25 [model_runner.py:281] Loading model from scratch...
# (Worker_TP0 pid=277) INFO 07-18 13:20:25 [model_runner.py:281] Loading model from scratch...
# (Worker_TP1 pid=278) ERROR 07-18 13:20:25 [fa_utils.py:253] Cannot use FA version 2 is not supported due to FA2 is only supported on devices with compute capability >= 8
# (Worker_TP0 pid=277) ERROR 07-18 13:20:25 [fa_utils.py:253] Cannot use FA version 2 is not supported due to FA2 is only supported on devices with compute capability >= 8
# (Worker_TP0 pid=277) INFO 07-18 13:20:25 [cuda.py:476] Using TRITON_ATTN attention backend out of potential backends: ['TRITON_ATTN', 'FLEX_ATTENTION'].
# (Worker_TP1 pid=278) Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# (Worker_TP0 pid=277) Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# model.safetensors.index.json: 27.8kB [00:00, 61.3MB/s]
# (Worker_TP1 pid=278) INFO 07-18 13:21:32 [weight_utils.py:530] Time spent downloading weights for Qwen/Qwen2.5-7B-Instruct: 65.894179 seconds
# (Worker_TP0 pid=277) INFO 07-18 13:21:32 [weight_utils.py:849] Filesystem type for checkpoints: OVERLAY. Checkpoint size: 14.19 GiB. Available RAM: 24.80 GiB.
# (Worker_TP0 pid=277) INFO 07-18 13:21:32 [weight_utils.py:872] Auto-prefetch is disabled because the filesystem (OVERLAY) is not a recognized network FS (NFS/Lustre). If you want to force prefetching, start vLLM with --safetensors-load-strategy=prefetch.
# Loading safetensors checkpoint shards:   0% Completed | 0/4 [00:00<?, ?it/s]
# Loading safetensors checkpoint shards:  25% Completed | 1/4 [00:05<00:16,  5.54s/it]
# Loading safetensors checkpoint shards:  50% Completed | 2/4 [00:12<00:12,  6.37s/it]
# Loading safetensors checkpoint shards:  75% Completed | 3/4 [00:20<00:07,  7.27s/it]
# Loading safetensors checkpoint shards: 100% Completed | 4/4 [00:39<00:00, 11.94s/it]
# Loading safetensors checkpoint shards: 100% Completed | 4/4 [00:39<00:00,  9.98s/it]
# (Worker_TP0 pid=277)
# (Worker_TP0 pid=277) INFO 07-18 13:22:12 [default_loader.py:430] Loading weights took 39.99 seconds
# (Worker_TP0 pid=277) INFO 07-18 13:22:13 [punica_selector.py:20] Using PunicaWrapperGPU.
# (Worker_TP0 pid=277) INFO 07-18 13:22:13 [model_runner.py:302] Model loading took 7.25 GiB and 108.872213 seconds
# (Worker_TP0 pid=277) INFO 07-18 13:22:13 [topk_topp_sampler.py:39] FlashInfer top-p/top-k sampling disabled via VLLM_USE_FLASHINFER_SAMPLER=0.
# (Worker_TP1 pid=278) INFO 07-18 13:22:13 [model_runner.py:302] Model loading took 7.25 GiB and 108.941089 seconds
# (Worker_TP0 pid=277) WARNING 07-18 13:22:22 [utils.py:279] Using default LoRA kernel configs
# (Worker_TP0 pid=277) INFO 07-18 13:22:36 [gpu_worker.py:538] Available KV cache memory: 5.28 GiB
# (EngineCore pid=250) INFO 07-18 13:22:36 [kv_cache_utils.py:2146] GPU KV cache size: 197,664 tokens
# (EngineCore pid=250) INFO 07-18 13:22:36 [kv_cache_utils.py:2147] Maximum concurrency for 4,096 tokens per request: 48.26x
# (Worker_TP1 pid=278) WARNING 07-18 13:22:36 [import_utils.py:408] Module vllm.third_party.deep_gemm was found but failed to import
# (Worker_TP1 pid=278) WARNING 07-18 13:22:36 [import_utils.py:408] Traceback (most recent call last):
# (Worker_TP1 pid=278) WARNING 07-18 13:22:36 [import_utils.py:408]   File "/usr/local/lib/python3.12/dist-packages/vllm/utils/import_utils.py", line 406, in _has_module
# (Worker_TP1 pid=278) WARNING 07-18 13:22:36 [import_utils.py:408]     importlib.import_module(module_name)
# (Worker_TP1 pid=278) WARNING 07-18 13:22:36 [import_utils.py:408]   File "/usr/lib/python3.12/importlib/__init__.py", line 90, in import_module
# (Worker_TP1 pid=278) WARNING 07-18 13:22:36 [import_utils.py:408]     return _bootstrap._gcd_import(name[level:], package, level)
# (Worker_TP1 pid=278) WARNING 07-18 13:22:36 [import_utils.py:408]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (Worker_TP1 pid=278) WARNING 07-18 13:22:36 [import_utils.py:408]   File "<frozen importlib._bootstrap>", line 1387, in _gcd_import
# (Worker_TP1 pid=278) WARNING 07-18 13:22:36 [import_utils.py:408]   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
# (Worker_TP1 pid=278) WARNING 07-18 13:22:36 [import_utils.py:408]   File "<frozen importlib._bootstrap>", line 1331, in _find_and_load_unlocked
# (Worker_TP1 pid=278) WARNING 07-18 13:22:36 [import_utils.py:408]   File "<frozen importlib._bootstrap>", line 935, in _load_unlocked
# (Worker_TP1 pid=278) WARNING 07-18 13:22:36 [import_utils.py:408]   File "<frozen importlib._bootstrap_external>", line 999, in exec_module
# (Worker_TP1 pid=278) WARNING 07-18 13:22:36 [import_utils.py:408]   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
# (Worker_TP1 pid=278) WARNING 07-18 13:22:36 [import_utils.py:408]   File "/usr/local/lib/python3.12/dist-packages/vllm/third_party/deep_gemm/__init__.py", line 16, in <module>
# (Worker_TP1 pid=278) WARNING 07-18 13:22:36 [import_utils.py:408]     from . import _C
# (Worker_TP1 pid=278) WARNING 07-18 13:22:36 [import_utils.py:408] ImportError: libnvrtc.so.13: cannot open shared object file: No such file or directory
# (Worker_TP1 pid=278) INFO 07-18 13:22:36 [cutedsl_warmup.py:97] Skipping CuTeDSL warmup because no compile units were requested.
# (Worker_TP0 pid=277) WARNING 07-18 13:22:36 [import_utils.py:408] Module vllm.third_party.deep_gemm was found but failed to import
# (Worker_TP0 pid=277) WARNING 07-18 13:22:36 [import_utils.py:408] Traceback (most recent call last):
# (Worker_TP0 pid=277) WARNING 07-18 13:22:36 [import_utils.py:408]   File "/usr/local/lib/python3.12/dist-packages/vllm/utils/import_utils.py", line 406, in _has_module
# (Worker_TP0 pid=277) WARNING 07-18 13:22:36 [import_utils.py:408]     importlib.import_module(module_name)
# (Worker_TP0 pid=277) WARNING 07-18 13:22:36 [import_utils.py:408]   File "/usr/lib/python3.12/importlib/__init__.py", line 90, in import_module
# (Worker_TP0 pid=277) WARNING 07-18 13:22:36 [import_utils.py:408]     return _bootstrap._gcd_import(name[level:], package, level)
# (Worker_TP0 pid=277) WARNING 07-18 13:22:36 [import_utils.py:408]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (Worker_TP0 pid=277) WARNING 07-18 13:22:36 [import_utils.py:408]   File "<frozen importlib._bootstrap>", line 1387, in _gcd_import
# (Worker_TP0 pid=277) WARNING 07-18 13:22:36 [import_utils.py:408]   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
# (Worker_TP0 pid=277) WARNING 07-18 13:22:36 [import_utils.py:408]   File "<frozen importlib._bootstrap>", line 1331, in _find_and_load_unlocked
# (Worker_TP0 pid=277) WARNING 07-18 13:22:36 [import_utils.py:408]   File "<frozen importlib._bootstrap>", line 935, in _load_unlocked
# (Worker_TP0 pid=277) WARNING 07-18 13:22:36 [import_utils.py:408]   File "<frozen importlib._bootstrap_external>", line 999, in exec_module
# (Worker_TP0 pid=277) WARNING 07-18 13:22:36 [import_utils.py:408]   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
# (Worker_TP0 pid=277) WARNING 07-18 13:22:36 [import_utils.py:408]   File "/usr/local/lib/python3.12/dist-packages/vllm/third_party/deep_gemm/__init__.py", line 16, in <module>
# (Worker_TP0 pid=277) WARNING 07-18 13:22:36 [import_utils.py:408]     from . import _C
# (Worker_TP0 pid=277) WARNING 07-18 13:22:36 [import_utils.py:408] ImportError: libnvrtc.so.13: cannot open shared object file: No such file or directory
# (Worker_TP0 pid=277) INFO 07-18 13:22:36 [cutedsl_warmup.py:97] Skipping CuTeDSL warmup because no compile units were requested.
# (Worker_TP1 pid=278) INFO 07-18 13:22:56 [jit_monitor.py:73] Kernel JIT monitor activated; monitored JIT compilations during inference will use mode=warn.
# (Worker_TP0 pid=277) INFO 07-18 13:22:56 [jit_monitor.py:73] Kernel JIT monitor activated; monitored JIT compilations during inference will use mode=warn.
# (EngineCore pid=250) INFO 07-18 13:22:56 [core.py:344] init engine (profile, create kv cache, warmup model) took 43.08 s
# (EngineCore pid=250) Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# (EngineCore pid=250) INFO 07-18 13:22:59 [vllm.py:1042] Asynchronous scheduling is enabled.
# (EngineCore pid=250) WARNING 07-18 13:22:59 [vllm.py:1096] Enforce eager set, disabling torch.compile and CUDAGraphs. This is equivalent to setting -cc.mode=none -cc.cudagraph_mode=none
# (EngineCore pid=250) WARNING 07-18 13:22:59 [vllm.py:1144] Inductor compilation was disabled by user settings, optimizations settings that are only active during inductor compilation will be ignored.
# (EngineCore pid=250) INFO 07-18 13:22:59 [kernel.py:292] Final IR op priority after setting platform defaults: IrOpPriorityConfig(rms_norm=['vllm_c', 'native'], fused_add_rms_norm=['vllm_c', 'native'])
# (EngineCore pid=250) INFO 07-18 13:22:59 [vllm.py:1322] Cudagraph is disabled under eager mode
# (EngineCore pid=250) INFO 07-18 13:22:59 [compilation.py:312] Enabled custom fusions: norm_quant, act_quant
# Rendering conversations:   0%|                            | 0/1 [00:00<?, ?it/s]INFO 07-18 13:23:01 [hf.py:548] Detected the chat template content format to be 'string'. You can set `--chat-template-content-format` to override this.
# Rendering conversations: 100%|████████████████████| 1/1 [00:01<00:00,  1.84s/it]
# Processed prompts:   0%| | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o(Worker_TP0 pid=277) WARNING 07-18 13:23:02 [jit_monitor.py:129] Triton kernel JIT compilation during inference: kernel_unified_attention. This causes a latency spike; consider extending warmup to cover this shape/config.
# (Worker_TP0 pid=277) WARNING 07-18 13:23:04 [jit_monitor.py:129] Triton kernel JIT compilation during inference: reduce_segments. This causes a latency spike; consider extending warmup to cover this shape/config.
# Processed prompts: 100%|█| 1/1 [00:19<00:00, 19.82s/it, est. speed input: 27.40
# Rendering conversations: 100%|███████████████████| 1/1 [00:00<00:00, 183.01it/s]
# Processed prompts: 100%|█| 1/1 [00:39<00:00, 39.42s/it, est. speed input: 13.98
# Rendering conversations: 100%|███████████████████| 1/1 [00:00<00:00, 215.06it/s]
# Processed prompts: 100%|█| 1/1 [00:14<00:00, 14.59s/it, est. speed input: 42.64
# Rendering conversations: 100%|███████████████████| 1/1 [00:00<00:00, 158.46it/s]
# Processed prompts: 100%|█| 1/1 [00:10<00:00, 10.70s/it, est. speed input: 43.63
# Rendering conversations: 100%|███████████████████| 1/1 [00:00<00:00, 139.62it/s]
# Processed prompts: 100%|█| 1/1 [00:24<00:00, 24.10s/it, est. speed input: 18.88
# Rendering conversations: 100%|███████████████████| 1/1 [00:00<00:00, 142.55it/s]
# Processed prompts: 100%|█| 1/1 [00:21<00:00, 21.55s/it, est. speed input: 21.86
# Rendering conversations: 100%|███████████████████| 1/1 [00:00<00:00, 238.11it/s]
# Processed prompts: 100%|█| 1/1 [00:14<00:00, 14.86s/it, est. speed input: 25.10
# Rendering conversations: 100%|███████████████████| 1/1 [00:00<00:00, 206.29it/s]
# Processed prompts: 100%|█| 1/1 [00:24<00:00, 24.44s/it, est. speed input: 22.22
# Rendering conversations: 100%|███████████████████| 1/1 [00:00<00:00, 258.25it/s]
# Processed prompts: 100%|█| 1/1 [00:18<00:00, 19.00s/it, est. speed input: 25.42
# Rendering conversations: 100%|███████████████████| 1/1 [00:00<00:00, 205.47it/s]
# Processed prompts: 100%|█| 1/1 [00:11<00:00, 11.54s/it, est. speed input: 49.83
# Rendering conversations: 100%|███████████████████| 1/1 [00:00<00:00, 236.17it/s]
# Processed prompts: 100%|█| 1/1 [00:16<00:00, 16.73s/it, est. speed input: 35.92
# Rendering conversations: 100%|███████████████████| 1/1 [00:00<00:00, 132.25it/s]
# Processed prompts: 100%|█| 1/1 [00:10<00:00, 10.64s/it, est. speed input: 57.44
# Rendering conversations: 100%|███████████████████| 1/1 [00:00<00:00, 150.35it/s]
# Processed prompts:   0%| | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
